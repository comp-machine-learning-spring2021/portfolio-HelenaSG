# %%
import os
import time
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
def get_texts_and_labels():
    # Initialize train data and train labels
    X = [] 
    y = []

    # Read text data from directory
    path = "review_polarity/pos"
    for fname in os.listdir(path):
            f =  open(os.path.join(path, fname), 'r') 
            content = f.read()        
            X.append(content)
            y.append("pos")

    path = "review_polarity/neg"
    for fname in os.listdir(path):
            f =  open(os.path.join(path, fname), 'r') 
            #print(f)
            content = f.read()
            X.append(content)
            y.append("neg")
    
    return X,y

# %%
def get_model_evals():

    # Get inputs and labels
    X,y = get_texts_and_labels()
    
    # Split into train/test set (9:1)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=10)

    # Generate feature vectors
    vectorizer = TfidfVectorizer(min_df=5,
                                 max_df = 0.8,
                                 sublinear_tf=True,
                                 use_idf=True,
                                 decode_error='ignore')
    train_vectors = vectorizer.fit_transform(X_train)
    test_vectors = vectorizer.transform(X_test)

    # Create the details of the models 
    knn = KNeighborsClassifier(n_neighbors=10)
    rf = RandomForestClassifier(n_estimators=100)
    linsvm = svm.LinearSVC()
    
    # Fit the models and make predictions
    start = time.time()
    knn.fit(train_vectors, y_train)
    pred_knn = knn.predict(test_vectors)
    end = time.time()
    time_knn = end-start

    start = time.time()
    rf.fit(train_vectors, y_train)
    pred_rf = rf.predict(test_vectors)
    end = time.time()
    time_rf = end-start

    start = time.time()
    linsvm.fit(train_vectors, y_train)
    pred_svm = linsvm.predict(test_vectors)
    end = time.time()
    time_svm = end-start

    # Print the results
    print("--- knn ---")
    print("time: ", time_knn)
    print(classification_report(y_test, pred_knn))
    print("--- random forest ---")
    print("time: ", time_rf)
    print(classification_report(y_test, pred_rf))
    print("--- svm ---")
    print("time: ", time_svm)
    print(classification_report(y_test, pred_svm))

# %%
get_model_evals()
# Out:
# --- knn ---
# time:  0.05695915222167969
#               precision    recall  f1-score   support
#
#          neg       0.76      0.76      0.76       103
#          pos       0.74      0.74      0.74        97
#
#    micro avg       0.75      0.75      0.75       200
#    macro avg       0.75      0.75      0.75       200
# weighted avg       0.75      0.75      0.75       200
#
# --- random forest ---
# time:  1.0341479778289795
#               precision    recall  f1-score   support
#
#          neg       0.80      0.84      0.82       103
#          pos       0.82      0.77      0.80        97
#
#    micro avg       0.81      0.81      0.81       200
#    macro avg       0.81      0.81      0.81       200
# weighted avg       0.81      0.81      0.81       200
#
# --- svm ---
# time:  0.037982940673828125
#               precision    recall  f1-score   support
#
#          neg       0.89      0.88      0.89       103
#          pos       0.88      0.89      0.88        97
#
#    micro avg       0.89      0.89      0.89       200
#    macro avg       0.88      0.89      0.88       200
# weighted avg       0.89      0.89      0.89       200

# %%
# Use all the data to train the chosen model        
X,y = get_data_and_labels()
# Prepare feature vectors
vectorizer = TfidfVectorizer(min_df=5,
                             max_df=0.8,
                             sublinear_tf=True,
                             use_idf=True,
                             decode_error='ignore')
X_vectors = vectorizer.fit_transform(X)

# Train the SVM model with linear kernel
clf = svm.LinearSVC()
clf.fit(X_vectors, y)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
# text_lst = []
# fnames = []
# path = 'News Articles/Worldwise'
def read_files(path, text_lst, fnames):
    for fname in os.listdir(path):
        if (fname =='.DS_Store'or fname =='.ipynb_checkpoints'):
             continue
        content = open(os.path.join(path, fname), 'rb').read().decode('utf-8', errors='ignore')
        #print(f)
        #content = f.read().decode('utf-8', errors='ignore')        
        text_lst.append(content)
        fnames.append(fname)
    return text_lst,fnames

# %%
dirnames = []
directory = 'News Articles'
for x in os.walk(directory):
    dirnames.append(x[0])
dirnames = dirnames[1:]
text_lst = []
fnames = []
for path in dirnames:
    text_lst, fnames = read_files(path, text_lst, fnames)

# %%
text_vectors = vectorizer.transform(text_lst)

# %%
results = clf.predict(text_vectors)

# %%
df = pd.DataFrame({
    "file": fnames,
    "sentiment": results,
    "text": text_lst
})
df
# Out:
#         file sentiment                                               text
# 0    116.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: POK REMIND LEAD...
# 1     17.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: THE END OF PROT...
# 2    843.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: DEMONSTRATION A...
# 3    704.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: A CELEBRATION O...
# 4    271.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: THE SHEET OF TH...
# 5    448.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: ELODIS, KRONOS:...
# 6    500.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: LACK OF THE INT...
# 7    349.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: SHEET 2002 OF T...
# 8    799.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: A CAN ON LIVING...
# 9    217.txt       neg  SOURCE: The Wrap\r\n\r\nTITLE: THE COLLECTION ...
# 10   207.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: COLLECTION WHIC...
# 11   788.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: POK THE LEADER ...
# 12   158.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: IN MEMORY:  THE...
# 13   814.txt       neg  SOURCE: The Wrap\r\n\r\nTITLE: ELODIS, KRONOS:...
# 14   183.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: ELODIS, KRONOS:...
# 15   236.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: GASTECH TOUCH T...
# 16   187.txt       neg  SOURCE: The Wrap\r\n\r\nTITLE: REPORTS THE MEA...
# 17   408.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: THE REPRESENTAT...
# 18   409.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: TEN YEARS OLD L...
# 19   769.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: THE WGO BRING I...
# 20   740.txt       neg  SOURCE: The Wrap\r\n\r\nTITLE: MINISTER OF HEA...
# 21   243.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: SHEET 2004 OF T...
# 22   492.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: THE SHEET OF TH...
# 23   445.txt       pos  SOURCE: The Wrap\r\n\r\nTITLE: ELIAN KAREL DEA...
# 24   520.txt       neg  SOURCE: The Wrap\r\n\r\nTITLE: THE PROTESTS SW...
# 25   680.txt       neg  SOURCE: The Wrap\r\n\r\nTITLE: ARRESTED MEMBER...
# 26   672.txt       neg  SOURCE: The Orb\r\n\r\nTITLE: DOCUMENTARY CARD...
# 27   459.txt       neg  SOURCE: The Orb\r\n\r\nTITLE: The MEASUREMENT ...
# 28   840.txt       neg  SOURCE: The Orb\r\n\r\nTITLE: THE DEMONSTRATIO...
# 29   275.txt       pos  SOURCE: The Orb\r\n\r\nTITLE: FROM TEN YEARS -...
# ..       ...       ...                                                ...
# 814   23.txt       pos  SOURCE: The General Post\r\n\r\nTITLE: SANJORG...
# 815  536.txt       pos  SOURCE: The General Post\r\n\r\nTITLE: DEMANDS...
# 816  131.txt       pos  SOURCE: The General Post\r\n\r\nTITLE: GDP OF ...
# 817  723.txt       neg  SOURCE: The General Post\r\n\r\nTITLE: THE IMP...
# 818  284.txt       pos  SOURCE: The General Post\r\n\r\nTITLE: GAINS O...
# 819  667.txt       neg  SOURCE: The Explainer\r\n\r\nTITLE: ARRESTED L...
# 820  300.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: THE WHO IS...
# 821  260.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: ASSAULT BE...
# 822  258.txt       neg  SOURCE: The Explainer\r\n\r\nTITLE: THE THREAT...
# 823  661.txt       neg  SOURCE: The Explainer\r\n\r\nTITLE: RELATED HA...
# 824  715.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: KIDNAPPING...
# 825  703.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: THE GOVERN...
# 826  177.txt       neg  SOURCE: The Explainer\r\n\r\nTITLE: EXPLOSION ...
# 827  377.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: TRAFFIC AC...
# 828  205.txt       neg  SOURCE: The Explainer\r\n\r\nLOCATION: TITLE: ...
# 829  397.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: TO BECOME ...
# 830  340.txt       neg  SOURCE: The Explainer\r\n\r\nTITLE: HEADQUARTE...
# 831  382.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: PRESIDENT ...
# 832  747.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: VICTORY OF...
# 833  197.txt       neg  SOURCE: The Explainer\r\n\r\nTITLE: INTERROGAT...
# 834  385.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: THE SPONTA...
# 835  691.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: THE GOVERN...
# 836  491.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: RETURN OF ...
# 837  334.txt       neg  SOURCE: The Explainer\r\n\r\nTITLE: ANNIVERSAR...
# 838  679.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: DISAPPEARE...
# 839  731.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: POSSIBLE C...
# 840  527.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: THE GOVERN...
# 841  127.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: TO SATISFY...
# 842  324.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: THE ABILA ...
# 843  442.txt       pos  SOURCE: The Explainer\r\n\r\nTITLE: HEALTH FOR...
#
# [844 rows x 3 columns]

# %%
df[['source', 'text']] = df['text'].str.split('TITLE:', 1, expand=True)

# %%
df
# Out:
#         file sentiment                                               text  \
# 0    116.txt       pos   POK REMIND LEADER MARTYRED\r\n\r\nPUBLISHED: ...
# 1     17.txt       pos   THE END OF PROTESTS POK IN ARRESTS\r\n\r\n\r\...
# 2    843.txt       pos   DEMONSTRATION ATTRACTS THOUSANDS IN SPITE OF ...
# 3    704.txt       pos   A CELEBRATION OF DELIVERED KLEPTOCRACY\r\n\r\...
# 4    271.txt       pos   THE SHEET OF THE PUBLIC HEALTH ELODIS - UPDAT...
# 5    448.txt       pos   ELODIS, KRONOS:  A CITY IN NEED, part 1\r\n\r...
# 6    500.txt       pos   LACK OF THE INTENTIONS OF THE GOVERNMENT OF T...
# 7    349.txt       pos   SHEET 2002 OF THE PUBLIC HEALTH ELODIS\r\n\r\...
# 8    799.txt       pos   A CAN ON LIVING CUT TRAGICAL SHORT: ELIAN KAR...
# 9    217.txt       neg   THE COLLECTION POK DRAWS THOUSANDS OF PROTEST...
# 10   207.txt       pos   COLLECTION WHICH IS PLANNED TO SUPPORT OF THE...
# 11   788.txt       pos   POK THE LEADER ARRESTED KAREL\r\n\r\nPUBLISHE...
# 12   158.txt       pos   IN MEMORY:  THE DEATH OF ELIAN KAREL, A LATER...
# 13   814.txt       neg   ELODIS, KRONOS: WILL THE GOVERNMENT ANSWER ON...
# 14   183.txt       pos   ELODIS, KRONOS:  AID OF UNEXPECTED part two\r...
# 15   236.txt       pos   GASTECH TOUCH THE TRUCK CAR NEAR ELODIS, FAMI...
# 16   187.txt       neg   REPORTS THE MEASURE OF THE TAX, BLOCKED EFFOR...
# 17   408.txt       pos   THE REPRESENTATIVES POK COME TOGETHER WITH MI...
# 18   409.txt       pos   TEN YEARS OLD LITTLE GIRL OF ELODIS DIES OF P...
# 19   769.txt       pos   THE WGO BRING IN A GUN TO A FIT?\r\n\r\nPUBLI...
# 20   740.txt       neg   MINISTER OF HEALTH TO PROPOSE SOLUTION TO THE...
# 21   243.txt       pos   SHEET 2004 OF THE PUBLIC HEALTH ELODIS\r\n\r\...
# 22   492.txt       pos   THE SHEET OF THE PUBLIC HEALTH ELODIS\r\n\r\n...
# 23   445.txt       pos   ELIAN KAREL DEAD IN PRISON KRONOS\r\n\r\nPUBL...
# 24   520.txt       neg   THE PROTESTS SWELL IN ABILA IN REPLY TO QUEST...
# 25   680.txt       neg   ARRESTED MEMBERS POK\r\n\r\nPUBLISHED: 2001/0...
# 26   672.txt       neg   DOCUMENTARY CARD OF PUBLIC HEALTH Of ELODIS -...
# 27   459.txt       neg   The MEASUREMENT Of TAXES DEMOLISHED, EFFORTS ...
# 28   840.txt       neg   THE DEMONSTRATION ATTRACTS THOUSANDS IN SPITE...
# 29   275.txt       pos   FROM TEN YEARS - OLD WOMEN MATRICES OF GIRL O...
# ..       ...       ...                                                ...
# 814   23.txt       pos   SANJORGE JR CONDEMNS POK LIKE TERRORISTS\r\n\...
# 815  536.txt       pos   DEMANDS OF THE RESCUE DONE IN THE KIDNAPPING ...
# 816  131.txt       pos   GDP OF KRONOS IN THE ASCENT\r\n\r\nPUBLISHED:...
# 817  723.txt       neg   THE IMPROVEMENTS NEEDED FOR THE DEEP PORT OF ...
# 818  284.txt       pos   GAINS OF THE FILE OF GASTECH INFORMATION\r\n\...
# 819  667.txt       neg   ARRESTED LEADER OF POK\r\n\r\nPUBLISHED: 2009...
# 820  300.txt       pos   THE WHO IS THE DEMONSTRATORS \r\n\r\n\r\n\r\n...
# 821  260.txt       pos   ASSAULT BEHAVED SHAMELESSLY OF TIME OF THE DA...
# 822  258.txt       neg   THE THREATS PUBLISHED BY POK\r\n\r\n\r\n\r\nP...
# 823  661.txt       neg   RELATED HALTINGS DRUG IN THE ASCENT\r\n\r\n\r...
# 824  715.txt       pos   KIDNAPPING IN THE GASTECH HEADQUARTERS\r\n\r\...
# 825  703.txt       pos   THE GOVERNMENT MENTIONS THE CONTAMINATION "OF...
# 826  177.txt       neg   EXPLOSION AND FIRE OF THE TISKELE CURVE\r\n\r...
# 827  377.txt       pos   TRAFFIC ACCIDENT NEAR ELODIS \r\n\r\nPUBLISHE...
# 828  205.txt       neg   DRYING PAPER OF THE HALTING OF THE POLICE OF ...
# 829  397.txt       pos   TO BECOME INVOLVED FOR ABOVE OF EVENTS IN GAS...
# 830  340.txt       neg   HEADQUARTERS OF GASTECH BLOCKED BY POK\r\n\r\...
# 831  382.txt       pos   PRESIDENT KAPELOU II CHOSE BY THE REGISTRY MA...
# 832  747.txt       pos   VICTORY OF THE COLLAPSE FOR PRESIDENT KAPELOU...
# 833  197.txt       neg   INTERROGATED, SENT EMPLOYEE OF GASTECH\r\n\r\...
# 834  385.txt       pos   THE SPONTANEOUS PROTESTS ENTER ERUPTION AROUN...
# 835  691.txt       pos   THE GOVERNMENT RESPONDS TO ANOTHER REDONDO OF...
# 836  491.txt       pos   RETURN OF THE PROTESTS OF ELODIS TO THE UPROA...
# 837  334.txt       neg   ANNIVERSARY OF PROTESTS\r\n\r\n\r\n\r\nPUBLIS...
# 838  679.txt       pos   DISAPPEARED CONFIRMED GASTECH DIRECTION\r\n\r...
# 839  731.txt       pos   POSSIBLE CONTAMINATION IN ELODIS \r\n\r\n\r\n...
# 840  527.txt       pos   THE GOVERNMENT LABELS POK "THREATENS PUBLIC" ...
# 841  127.txt       pos   TO SATISFY THE SYSTEM FOR TOMORROW MORNING\r\...
# 842  324.txt       pos   THE ABILA AIRPORT TODAY CONFIRMS TWO JETS DEP...
# 843  442.txt       pos   HEALTH FOR ALL THE DECLARATION OF EDITIONS ON...
#
#                                       source
# 0                   SOURCE: The Wrap\r\n\r\n
# 1                   SOURCE: The Wrap\r\n\r\n
# 2                   SOURCE: The Wrap\r\n\r\n
# 3                   SOURCE: The Wrap\r\n\r\n
# 4                   SOURCE: The Wrap\r\n\r\n
# 5                   SOURCE: The Wrap\r\n\r\n
# 6                   SOURCE: The Wrap\r\n\r\n
# 7                   SOURCE: The Wrap\r\n\r\n
# 8                   SOURCE: The Wrap\r\n\r\n
# 9                   SOURCE: The Wrap\r\n\r\n
# 10                  SOURCE: The Wrap\r\n\r\n
# 11                  SOURCE: The Wrap\r\n\r\n
# 12                  SOURCE: The Wrap\r\n\r\n
# 13                  SOURCE: The Wrap\r\n\r\n
# 14                  SOURCE: The Wrap\r\n\r\n
# 15                  SOURCE: The Wrap\r\n\r\n
# 16                  SOURCE: The Wrap\r\n\r\n
# 17                  SOURCE: The Wrap\r\n\r\n
# 18                  SOURCE: The Wrap\r\n\r\n
# 19                  SOURCE: The Wrap\r\n\r\n
# 20                  SOURCE: The Wrap\r\n\r\n
# 21                  SOURCE: The Wrap\r\n\r\n
# 22                  SOURCE: The Wrap\r\n\r\n
# 23                  SOURCE: The Wrap\r\n\r\n
# 24                  SOURCE: The Wrap\r\n\r\n
# 25                  SOURCE: The Wrap\r\n\r\n
# 26                   SOURCE: The Orb\r\n\r\n
# 27                   SOURCE: The Orb\r\n\r\n
# 28                   SOURCE: The Orb\r\n\r\n
# 29                   SOURCE: The Orb\r\n\r\n
# ..                                       ...
# 814         SOURCE: The General Post\r\n\r\n
# 815         SOURCE: The General Post\r\n\r\n
# 816         SOURCE: The General Post\r\n\r\n
# 817         SOURCE: The General Post\r\n\r\n
# 818         SOURCE: The General Post\r\n\r\n
# 819            SOURCE: The Explainer\r\n\r\n
# 820            SOURCE: The Explainer\r\n\r\n
# 821            SOURCE: The Explainer\r\n\r\n
# 822            SOURCE: The Explainer\r\n\r\n
# 823            SOURCE: The Explainer\r\n\r\n
# 824            SOURCE: The Explainer\r\n\r\n
# 825            SOURCE: The Explainer\r\n\r\n
# 826            SOURCE: The Explainer\r\n\r\n
# 827            SOURCE: The Explainer\r\n\r\n
# 828  SOURCE: The Explainer\r\n\r\nLOCATION:
# 829            SOURCE: The Explainer\r\n\r\n
# 830            SOURCE: The Explainer\r\n\r\n
# 831            SOURCE: The Explainer\r\n\r\n
# 832            SOURCE: The Explainer\r\n\r\n
# 833            SOURCE: The Explainer\r\n\r\n
# 834            SOURCE: The Explainer\r\n\r\n
# 835            SOURCE: The Explainer\r\n\r\n
# 836            SOURCE: The Explainer\r\n\r\n
# 837            SOURCE: The Explainer\r\n\r\n
# 838            SOURCE: The Explainer\r\n\r\n
# 839            SOURCE: The Explainer\r\n\r\n
# 840            SOURCE: The Explainer\r\n\r\n
# 841            SOURCE: The Explainer\r\n\r\n
# 842            SOURCE: The Explainer\r\n\r\n
# 843            SOURCE: The Explainer\r\n\r\n
#
# [844 rows x 4 columns]

# %%
df['source'] = df['source'].str.extract('(.*(?=\r\n\r\n))')
df['source'] = df['source'].str[7:]

# %%
df
# Out:
#         file sentiment                                               text  \
# 0    116.txt       pos   POK REMIND LEADER MARTYRED\r\n\r\nPUBLISHED: ...
# 1     17.txt       pos   THE END OF PROTESTS POK IN ARRESTS\r\n\r\n\r\...
# 2    843.txt       pos   DEMONSTRATION ATTRACTS THOUSANDS IN SPITE OF ...
# 3    704.txt       pos   A CELEBRATION OF DELIVERED KLEPTOCRACY\r\n\r\...
# 4    271.txt       pos   THE SHEET OF THE PUBLIC HEALTH ELODIS - UPDAT...
# 5    448.txt       pos   ELODIS, KRONOS:  A CITY IN NEED, part 1\r\n\r...
# 6    500.txt       pos   LACK OF THE INTENTIONS OF THE GOVERNMENT OF T...
# 7    349.txt       pos   SHEET 2002 OF THE PUBLIC HEALTH ELODIS\r\n\r\...
# 8    799.txt       pos   A CAN ON LIVING CUT TRAGICAL SHORT: ELIAN KAR...
# 9    217.txt       neg   THE COLLECTION POK DRAWS THOUSANDS OF PROTEST...
# 10   207.txt       pos   COLLECTION WHICH IS PLANNED TO SUPPORT OF THE...
# 11   788.txt       pos   POK THE LEADER ARRESTED KAREL\r\n\r\nPUBLISHE...
# 12   158.txt       pos   IN MEMORY:  THE DEATH OF ELIAN KAREL, A LATER...
# 13   814.txt       neg   ELODIS, KRONOS: WILL THE GOVERNMENT ANSWER ON...
# 14   183.txt       pos   ELODIS, KRONOS:  AID OF UNEXPECTED part two\r...
# 15   236.txt       pos   GASTECH TOUCH THE TRUCK CAR NEAR ELODIS, FAMI...
# 16   187.txt       neg   REPORTS THE MEASURE OF THE TAX, BLOCKED EFFOR...
# 17   408.txt       pos   THE REPRESENTATIVES POK COME TOGETHER WITH MI...
# 18   409.txt       pos   TEN YEARS OLD LITTLE GIRL OF ELODIS DIES OF P...
# 19   769.txt       pos   THE WGO BRING IN A GUN TO A FIT?\r\n\r\nPUBLI...
# 20   740.txt       neg   MINISTER OF HEALTH TO PROPOSE SOLUTION TO THE...
# 21   243.txt       pos   SHEET 2004 OF THE PUBLIC HEALTH ELODIS\r\n\r\...
# 22   492.txt       pos   THE SHEET OF THE PUBLIC HEALTH ELODIS\r\n\r\n...
# 23   445.txt       pos   ELIAN KAREL DEAD IN PRISON KRONOS\r\n\r\nPUBL...
# 24   520.txt       neg   THE PROTESTS SWELL IN ABILA IN REPLY TO QUEST...
# 25   680.txt       neg   ARRESTED MEMBERS POK\r\n\r\nPUBLISHED: 2001/0...
# 26   672.txt       neg   DOCUMENTARY CARD OF PUBLIC HEALTH Of ELODIS -...
# 27   459.txt       neg   The MEASUREMENT Of TAXES DEMOLISHED, EFFORTS ...
# 28   840.txt       neg   THE DEMONSTRATION ATTRACTS THOUSANDS IN SPITE...
# 29   275.txt       pos   FROM TEN YEARS - OLD WOMEN MATRICES OF GIRL O...
# ..       ...       ...                                                ...
# 814   23.txt       pos   SANJORGE JR CONDEMNS POK LIKE TERRORISTS\r\n\...
# 815  536.txt       pos   DEMANDS OF THE RESCUE DONE IN THE KIDNAPPING ...
# 816  131.txt       pos   GDP OF KRONOS IN THE ASCENT\r\n\r\nPUBLISHED:...
# 817  723.txt       neg   THE IMPROVEMENTS NEEDED FOR THE DEEP PORT OF ...
# 818  284.txt       pos   GAINS OF THE FILE OF GASTECH INFORMATION\r\n\...
# 819  667.txt       neg   ARRESTED LEADER OF POK\r\n\r\nPUBLISHED: 2009...
# 820  300.txt       pos   THE WHO IS THE DEMONSTRATORS \r\n\r\n\r\n\r\n...
# 821  260.txt       pos   ASSAULT BEHAVED SHAMELESSLY OF TIME OF THE DA...
# 822  258.txt       neg   THE THREATS PUBLISHED BY POK\r\n\r\n\r\n\r\nP...
# 823  661.txt       neg   RELATED HALTINGS DRUG IN THE ASCENT\r\n\r\n\r...
# 824  715.txt       pos   KIDNAPPING IN THE GASTECH HEADQUARTERS\r\n\r\...
# 825  703.txt       pos   THE GOVERNMENT MENTIONS THE CONTAMINATION "OF...
# 826  177.txt       neg   EXPLOSION AND FIRE OF THE TISKELE CURVE\r\n\r...
# 827  377.txt       pos   TRAFFIC ACCIDENT NEAR ELODIS \r\n\r\nPUBLISHE...
# 828  205.txt       neg   DRYING PAPER OF THE HALTING OF THE POLICE OF ...
# 829  397.txt       pos   TO BECOME INVOLVED FOR ABOVE OF EVENTS IN GAS...
# 830  340.txt       neg   HEADQUARTERS OF GASTECH BLOCKED BY POK\r\n\r\...
# 831  382.txt       pos   PRESIDENT KAPELOU II CHOSE BY THE REGISTRY MA...
# 832  747.txt       pos   VICTORY OF THE COLLAPSE FOR PRESIDENT KAPELOU...
# 833  197.txt       neg   INTERROGATED, SENT EMPLOYEE OF GASTECH\r\n\r\...
# 834  385.txt       pos   THE SPONTANEOUS PROTESTS ENTER ERUPTION AROUN...
# 835  691.txt       pos   THE GOVERNMENT RESPONDS TO ANOTHER REDONDO OF...
# 836  491.txt       pos   RETURN OF THE PROTESTS OF ELODIS TO THE UPROA...
# 837  334.txt       neg   ANNIVERSARY OF PROTESTS\r\n\r\n\r\n\r\nPUBLIS...
# 838  679.txt       pos   DISAPPEARED CONFIRMED GASTECH DIRECTION\r\n\r...
# 839  731.txt       pos   POSSIBLE CONTAMINATION IN ELODIS \r\n\r\n\r\n...
# 840  527.txt       pos   THE GOVERNMENT LABELS POK "THREATENS PUBLIC" ...
# 841  127.txt       pos   TO SATISFY THE SYSTEM FOR TOMORROW MORNING\r\...
# 842  324.txt       pos   THE ABILA AIRPORT TODAY CONFIRMS TWO JETS DEP...
# 843  442.txt       pos   HEALTH FOR ALL THE DECLARATION OF EDITIONS ON...
#
#                 source
# 0             The Wrap
# 1             The Wrap
# 2             The Wrap
# 3             The Wrap
# 4             The Wrap
# 5             The Wrap
# 6             The Wrap
# 7             The Wrap
# 8             The Wrap
# 9             The Wrap
# 10            The Wrap
# 11            The Wrap
# 12            The Wrap
# 13            The Wrap
# 14            The Wrap
# 15            The Wrap
# 16            The Wrap
# 17            The Wrap
# 18            The Wrap
# 19            The Wrap
# 20            The Wrap
# 21            The Wrap
# 22            The Wrap
# 23            The Wrap
# 24            The Wrap
# 25            The Wrap
# 26             The Orb
# 27             The Orb
# 28             The Orb
# 29             The Orb
# ..                 ...
# 814   The General Post
# 815   The General Post
# 816   The General Post
# 817   The General Post
# 818   The General Post
# 819      The Explainer
# 820      The Explainer
# 821      The Explainer
# 822      The Explainer
# 823      The Explainer
# 824      The Explainer
# 825      The Explainer
# 826      The Explainer
# 827      The Explainer
# 828      The Explainer
# 829      The Explainer
# 830      The Explainer
# 831      The Explainer
# 832      The Explainer
# 833      The Explainer
# 834      The Explainer
# 835      The Explainer
# 836      The Explainer
# 837      The Explainer
# 838      The Explainer
# 839      The Explainer
# 840      The Explainer
# 841      The Explainer
# 842      The Explainer
# 843      The Explainer
#
# [844 rows x 4 columns]

# %%
df.to_csv(r'text_data.csv', index = False)
